# %% [markdown]
# # League Analysis and Graphing (LAG)
#
# [nbviewer link to render graphs](http://nbviewer.ipython.org/urls/raw.github.com/joeeoj/fantasy-football/main/2021/lag.ipynb)
#
# ## League rules
#
# * 12 teams
# * 0.5 PPR
# * 1 QB, 2 RB, 3 WR, 1 TE, 1 FLEX (RB/WR/TE), 1 DST, 1 K
# * auction draft - \$200
# * waivers - \$100 (Free-Agent Acquisition Budget / FAAB)
#
# ## LAG analysis

# %%
from pathlib import Path
from typing import List

import altair as alt
import pandas as pd

pd.set_option('max_columns', 100)

# %%
DATA_DIR = Path.cwd() / 'data'

# %%
# actual 2020 league data
df = pd.read_csv(DATA_DIR / 'player_points_2020.csv')

# don't need this in our league
df = df[df['position'] != 'DT']

df['rank'] = df.groupby('position')['total_points'].rank(method='first', ascending=False).astype(int)

df = df.sort_values(['position', 'rank'], ascending=[False, True])

df.head()
# Out:
#           id             name position  total_points  rank
# 78     16800    Davante Adams       WR         300.9     1
# 111  3116406      Tyreek Hill       WR         285.4     2
# 113  2976212     Stefon Diggs       WR         265.1     3
# 175  3925357    Calvin Ridley       WR         236.5     4
# 49     15795  DeAndre Hopkins       WR         230.3     5

# %%
m = (df['rank'] > 0) & (df['rank'] < 21)
pos_points_ranked = (pd.pivot_table(df[m], index='rank', columns='position',
                                    values='total_points', aggfunc='sum')
                       .astype(int))

pos_points_ranked
# Out:
# position  D/ST    K   QB   RB   TE   WR
# rank
# 1          174  169  395  336  260  300
# 2          164  166  382  323  225  285
# 3          157  153  378  315  150  265
# 4          146  151  374  237  141  236
# 5          145  146  369  235  141  230
# 6          137  145  359  234  140  230
# 7          127  142  343  225  132  229
# 8          127  142  337  214  126  217
# 9          117  138  332  199  121  215
# 10         112  137  332  199  119  213
# 11         112  132  306  197  118  212
# 12         111  132  282  184  118  211
# 13         110  130  272  182  115  200
# 14         107  130  267  179  115  195
# 15         102  128  260  177  113  191
# 16         101  122  259  172  109  190
# 17         100  121  248  169  108  189
# 18         100  121  241  166  106  185
# 19          97  120  239  163  101  183
# 20          95  111  239  161   93  180

# %%
pos_sort = ['QB', 'RB', 'WR', 'TE', 'K', 'D/ST']

(alt.Chart(df)
    .mark_line()
    .encode(x='rank', y='total_points', color=alt.Color('position', sort=pos_sort),
            tooltip=['total_points', 'name', 'position'])
    .transform_filter((alt.datum.rank > 0) & (alt.datum.rank < 21))
    .properties(width=600, height=400)
    .interactive())
# Out:
# alt.Chart(...)

# %% [markdown]
# ### All QBs

# %%
(alt.Chart(df)
    .mark_point()
    .encode(x='rank', y='total_points', tooltip=['name', 'total_points', 'rank'])
    .transform_filter((alt.datum.position == 'QB'))
    .properties(width=600, height=400)
    .interactive())
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3-10-20
#
# Compare the decline in score by position by averaging semi-arbitrary groups of ranks: 1-3, 4-10, and 11-20.

# %%
three = df[(df['rank'] > 0) & (df['rank'] <= 3)].groupby('position')['total_points'].mean().reset_index()
three['label'] = 'top_3_avg'

ten = df[(df['rank'] > 3) & (df['rank'] <= 10)].groupby('position')['total_points'].mean().reset_index()
ten['label'] = '4_to_10_avg'

twenty = df[(df['rank'] > 10) & (df['rank'] <= 20)].groupby('position')['total_points'].mean().reset_index()
twenty['label'] = '11_to_20_avg'

three_ten_twenty = pd.pivot_table(pd.concat([three, ten, twenty]), index='position', columns='label', values='total_points', aggfunc='sum').astype(int)

three_ten_twenty['drop_3_to_10'] = three_ten_twenty['top_3_avg'] - three_ten_twenty['4_to_10_avg']
three_ten_twenty['drop_11_to_20'] = three_ten_twenty['4_to_10_avg'] - three_ten_twenty['11_to_20_avg']
three_ten_twenty['drop_3_to_20'] = three_ten_twenty['top_3_avg'] - three_ten_twenty['11_to_20_avg']

# figure 3.3 ordering
three_ten_twenty = three_ten_twenty[['top_3_avg', '4_to_10_avg', 'drop_3_to_10', '11_to_20_avg', 'drop_11_to_20', 'drop_3_to_20']]
three_ten_twenty = three_ten_twenty.reindex(['QB', 'RB', 'WR', 'TE', 'K', 'D/ST'])

three_ten_twenty
# Out:
# label     top_3_avg  4_to_10_avg  drop_3_to_10  11_to_20_avg  drop_11_to_20  \
# position
# QB              385          350            35           261             89
# RB              325          221           104           175             46
# WR              283          224            59           194             30
# TE              211          131            80           110             21
# K               162          143            19           124             19
# D/ST            165          130            35           103             27
#
# label     drop_3_to_20
# position
# QB                 124
# RB                 150
# WR                  89
# TE                 101
# K                   38
# D/ST                62

# %% [markdown]
# ### drops by tier

# %%
drop_cols_only = three_ten_twenty[[c for c in three_ten_twenty.columns if c.startswith('drop')]]
drop_cols_only
# Out:
# label     drop_3_to_10  drop_11_to_20  drop_3_to_20
# position
# QB                  35             89           124
# RB                 104             46           150
# WR                  59             30            89
# TE                  80             21           101
# K                   19             19            38
# D/ST                35             27            62

# %%
def pos_avg_line_chart(t: pd.DataFrame, label_sort: List[str] = None) -> alt.vegalite.v4.api.Chart:
    return (alt.Chart(t)
               .mark_line(point={'size': 50})
               .encode(x=alt.X('label', sort=label_sort), y='value', color='position', tooltip=['position', 'value'])
               .properties(width=600, height=400)
               .interactive())

# %%
t = drop_cols_only.reset_index().melt(id_vars=['position'], value_vars=drop_cols_only.columns)
label_sort = ['drop_3_to_10', 'drop_11_to_20', 'drop_3_to_20']

pos_avg_line_chart(t, label_sort)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### tiers instead of drops (diffs)

# %%
avgs_only = three_ten_twenty[[c for c in three_ten_twenty.columns if not c.startswith('drop')]]
t = avgs_only.reset_index().melt(id_vars=['position'], value_vars=avgs_only.columns)

pos_avg_line_chart(t)
# Out:
# alt.Chart(...)
